# %%
import pandas as pd
import numpy as np
from pydataset import data
import math as math
import matplotlib.pyplot as plt

from env import host, user, password

url = f'mysql+pymysql://{user}:{password}@{host}/employees'

import seaborn as sns

# %%
telco = pd.read_csv('telco.csv')

# %%
recent_customer = telco[telco.monthly_tenure < 3]

# %%
recent_customer
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 17    0021-IKXGC  Female                1.0      No         No            2.0
# 19    0023-HGHWL    Male                1.0      No         No            0.0
# 23    0030-FNXPP  Female                0.0      No         No            1.0
# 25    0032-PGELS  Female                0.0     Yes        Yes            0.0
# 40    0067-DKWBL    Male                1.0      No         No            1.0
# ...          ...     ...                ...     ...        ...            ...
# 7007  9940-RHLFB  Female                0.0      No         No            1.0
# 7021  9962-BFPDU  Female                0.0     Yes        Yes            1.0
# 7033  9975-SKRNR    Male                0.0      No         No            1.0
# 7036  9985-MWVIX  Female                0.0      No         No            1.0
# 7040  9992-UJOEL    Male                0.0      No         No            1.0
#
#       internet_service  contract_type               payment_type  \
# 17                 2.0            0.0           Electronic check
# 19                 1.0            0.0           Electronic check
# 23                 0.0            0.0               Mailed check
# 25                 1.0            0.0  Bank transfer (automatic)
# 40                 1.0            0.0           Electronic check
# ...                ...            ...                        ...
# 7007               2.0            0.0           Electronic check
# 7021               0.0            0.0               Mailed check
# 7033               0.0            0.0               Mailed check
# 7036               2.0            0.0               Mailed check
# 7040               1.0            0.0               Mailed check
#
#       monthly_charges  ...  partner_dependents start_date  monthly_charges.1  \
# 17              72.10  ...                 0.0  7/20/2020               72.1
# 19              25.10  ...                 0.0  7/20/2020               25.1
# 23              19.85  ...                 0.0  6/20/2020              19.85
# 25              30.50  ...                 3.0  7/20/2020               30.5
# 40              49.25  ...                 0.0  7/20/2020              49.25
# ...               ...  ...                 ...        ...                ...
# 7007            75.30  ...                 0.0  7/20/2020               75.3
# 7021            20.05  ...                 3.0  7/20/2020              20.05
# 7033            18.90  ...                 0.0  7/20/2020               18.9
# 7036            70.15  ...                 0.0  7/20/2020              70.15
# 7040            50.30  ...                 0.0  7/20/2020               50.3
#
#      subscription_type phone_service_type internet_service_type phone_asvalue  \
# 17      Month-to-Month  Two or More Lines           Fiber Optic             1
# 19      Month-to-Month   No Phone Service                   DSL             0
# 23      Month-to-Month           One Line   No Internet Service             1
# 25      Month-to-Month   No Phone Service                   DSL             0
# 40      Month-to-Month           One Line                   DSL             1
# ...                ...                ...                   ...           ...
# 7007    Month-to-Month           One Line           Fiber Optic             1
# 7021    Month-to-Month           One Line   No Internet Service             1
# 7033    Month-to-Month           One Line   No Internet Service             1
# 7036    Month-to-Month           One Line           Fiber Optic             1
# 7040    Month-to-Month           One Line                   DSL             1
#
#      internet_asvalue  phone&int_asvalue Tenure Quartiles
# 17                  1                  1              NaN
# 19                  1                  0              NaN
# 23                  0                  0              NaN
# 25                  1                  0              NaN
# 40                  1                  1              NaN
# ...               ...                ...              ...
# 7007                1                  1              NaN
# 7021                0                  0              NaN
# 7033                0                  0              NaN
# 7036                1                  1              NaN
# 7040                1                  1              NaN
#
# [961 rows x 28 columns]
