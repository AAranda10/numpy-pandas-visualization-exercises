# %%
import math
import matplotlib.pyplot as plt

x1 = range(1, 20)
x2 = range(0, 20)

y1 = [0*n + 1 for n in x2]
y2 = [math.log(n) for n in x1]
y3 = [n for n in x2]
y4 = [n * math.log(n) for n in x1]
y5 = [pow(n, 2) for n in x2]
y6 = [pow(2, n) for n in x2]
y7 = [math.factorial(n) for n in x1]
y8 = [pow(n, n) for n in x2]

plt.plot(y1, label= '$O(1)$')
plt.plot(y2, label= '$O(log n)$')
plt.plot(y3, label= '$O(n)$')
plt.plot(y4, label= '$O(n log n)$')
plt.plot(y5, label= '$O(n^2)$')
plt.plot(y6, label= '$O(2^n)$')
plt.plot(y7, label= '$O(n!)$')
plt.plot(y8, label= '$O(n^n)$')

plt.title('Big O Notation')
plt.xlabel('Elements')
plt.ylabel('Operations')

plt.ylim(0, 20)
plt.xlim(0, 20)
plt.legend(loc = 'lower right')

# %%
plt.plot([5, 11], [5, 5], c= 'royalblue')
plt.plot([11, 11], [5, 7], c= 'royalblue')
plt.plot([11, 14], [7, 7], c= 'royalblue')
plt.plot([14, 14], [7, 10], c= 'royalblue')
plt.plot([14, 12.5], [11, 11], c= 'royalblue')
plt.plot([14, 16], [7, 7], c= 'brown')
plt.plot([16, 16], [7, 14], c= 'brown')
plt.plot([16, 15], [14, 14], c= 'brown')
plt.plot([15, 15], [14, 12], c= 'brown')
plt.plot([15, 14], [12, 12], c= 'brown')
plt.plot([14, 14], [12, 7], c= 'brown')
plt.plot([5, 5], [5, 7], c= 'royalblue')
plt.plot([5, 6], [7, 7], c= 'royalblue')
plt.plot([6, 6], [7, 8.5], c= 'royalblue')
plt.plot([6, 4], [8.5, 8.5], c= 'royalblue')
plt.plot([4, 4], [8.5, 10], c= 'royalblue')
plt.plot([4, 5], [10, 10], c= 'royalblue')
plt.plot([5, 5], [10, 8.5], c= 'royalblue')
plt.plot([5, 5], [5, 7], c= 'brown')
plt.plot([5, 6], [7, 7], c= 'brown')
plt.plot([6, 6], [7, 8.5], c= 'brown')
plt.plot([6, 2.5], [8.5, 8.5], c= 'brown')
plt.plot([2.5, 2.5], [8.5, 6.5], c= 'brown')
plt.plot([2.5, 1], [6.5, 6.5], c= 'brown')
plt.plot([1, 1], [6.5, 3.5], c= 'brown')
plt.plot([1, 3.5], [3.5, 3.5], c= 'brown')
plt.plot([3.5, 3.5], [3.5, 5], c= 'brown')
plt.plot([3.5, 5], [5, 5], c= 'brown')
plt.plot([5, 6], [8.5, 8.5], c= 'red')
plt.plot([6, 6], [8.5, 10], c= 'red')
plt.plot([6, 7], [10, 10], c= 'red')
plt.plot([7, 7], [10, 13], c= 'red')
plt.plot([7, 6], [13, 13], c= 'red')
plt.plot([6, 6], [13, 14], c= 'red')
plt.plot([6, 2.5], [14, 14], c= 'red')
plt.plot([2.5, 2.5], [14, 11], c= 'red')
plt.plot([2.5, 3.5], [11, 11], c= 'red')
plt.plot([3.5, 3.5], [11, 10], c= 'red')
plt.plot([3.5, 5], [10, 10], c= 'red')
plt.plot([5, 5], [10, 8.5], c= 'red')
plt.plot([2.5, 0], [12.5, 12.5], c= 'navajowhite')
plt.plot([0, 0], [12.5, 10], c= 'navajowhite')
plt.plot([0, 1], [10, 10], c= 'navajowhite')
plt.plot([1, 1], [10, 8.5], c= 'navajowhite')
plt.plot([1, 2], [8.5, 8.5], c= 'navajowhite')
plt.plot([2, 2], [8.5, 10], c= 'navajowhite')
plt.plot([2, 3.5], [10, 10], c= 'navajowhite')
plt.plot([6, 7], [14, 14], c= 'royalblue')
plt.plot([7, 7], [14, 13], c= 'royalblue')
plt.plot([7, 8], [13, 13], c= 'royalblue')
plt.plot([8, 8], [13, 11], c= 'royalblue')
plt.plot([8, 14], [11, 11], c= 'royalblue')
plt.plot([12.5, 12.5], [11, 12.5], c= 'royalblue')
plt.plot([12.5, 11.5], [12.5, 12.5], c= 'royalblue')
plt.plot([11.5, 11.5], [12.5, 11], c= 'royalblue')
plt.plot([11.5, 10.5], [12.5, 12.5], c= 'royalblue')
plt.plot([10.5, 10.5], [12.5, 14], c= 'royalblue')
plt.plot([10.5, 11.5], [14, 14], c= 'royalblue')
plt.plot([11.5, 11.5], [14, 12], c= 'royalblue')
plt.plot([5, 12.5], [14, 14], c= 'navajowhite')
plt.plot([5, 5], [14, 20], c= 'navajowhite')
plt.plot([5, 4], [20, 20], c= 'brown')
plt.plot([4, 4], [20, 17], c= 'navajowhite')
plt.plot([4, 5], [17, 17], c= 'navajowhite')
plt.plot([5, 7], [17, 17], c= 'brown')
plt.plot([7, 7], [17, 18.5], c= 'brown')
plt.plot([7, 6], [18.5, 18.5], c= 'brown')
plt.plot([6, 6], [18.5, 20], c= 'brown')
plt.plot([6, 7], [20, 20], c= 'brown')
plt.plot([7, 7], [20, 21.5], c= 'brown')
plt.plot([7, 4], [21.5, 21.5], c= 'brown')
plt.plot([4, 4], [21.5, 20], c= 'brown')
plt.plot([4, 3], [20, 20], c= 'brown')
plt.plot([3, 3], [20, 16], c= 'brown')
plt.plot([3, 5], [16, 16], c= 'brown')
plt.plot([5, 5], [16, 17], c= 'brown')
plt.plot([7, 13], [21.5, 21.5], c= 'red')
plt.plot([13, 13], [21.5, 23], c= 'red')
plt.plot([13, 10.5], [23, 23], c= 'red')
plt.plot([10.5, 10.5], [23, 25], c= 'red')
plt.plot([10.5, 5.5], [25, 25], c= 'red')
plt.plot([5.5, 5.5], [25, 23], c= 'red')
plt.plot([5.5, 4], [23, 23], c= 'red')
plt.plot([4, 4], [23, 21.5], c= 'red')
plt.plot([12.5, 12.5], [14, 16], c= 'navajowhite')
plt.plot([12.5, 9.5], [16, 16], c= 'black')
plt.plot([9.5, 9.5], [16, 17], c= 'black')
plt.plot([9.5, 10.5], [17, 17], c= 'black')
plt.plot([10.5, 10.5], [17, 18], c= 'black')
plt.plot([10.5, 11.5], [18, 18], c= 'black')
plt.plot([11.5, 11.5], [18, 17], c= 'black')
plt.plot([11.5, 13], [17, 17], c= 'black')
plt.plot([13, 13], [17, 16], c= 'black')
plt.plot([13, 12], [16, 16], c= 'black')
plt.plot([10.5, 10.5], [17, 21], c= 'black')
plt.plot([10.5, 9.5], [18, 18], c= 'black')
plt.plot([9.5, 9.5], [18, 21], c= 'black')
plt.plot([9.5, 10.5], [21, 21], c= 'black')
plt.plot([13, 14.5], [17, 17], c= 'navajowhite')
plt.plot([14.5, 14.5], [17, 19], c= 'navajowhite')
plt.plot([14.5, 13], [19, 19], c= 'navajowhite')
plt.plot([13, 13], [19, 20], c= 'navajowhite')
plt.plot([13, 12], [20, 20], c= 'navajowhite')
plt.plot([12, 12], [20, 21.5], c= 'navajowhite')
plt.plot([12.5, 13.5], [12.5, 12.5], c= 'red')
plt.plot([13.5, 13.5], [12.5, 14], c= 'red')
plt.plot([13.5, 14.5], [14, 14], c= 'red')
plt. plot([14.5, 14.5], [14, 17], c= 'red')
plt.plot([14.5, 15.5], [17, 17], c= 'red')
plt.plot([15.5, 15.5], [17, 21.5], c= 'red')
plt.plot([15.5, 13], [21.5, 21.5], c= 'red')
plt.plot([13, 13], [21.5, 19], c= 'red')
plt.plot([13, 13], [23, 24], c= 'navajowhite')
plt.plot([13, 15.5], [24.5, 24.5], c= 'navajowhite')
plt.plot([15.5, 15.5], [24.5, 21.5], c= 'navajowhite')
plt.plot([8, 8], [8, 9.5], c= 'gold')
plt.plot([8, 9], [9.5, 9.5], c= 'gold')
plt.plot([8, 9], [8, 8], c= 'gold')
plt.plot([9, 9], [8, 9.5], c= 'gold')
plt.plot([11.5, 11.5], [9.5, 11], c= 'gold')
plt.plot([12.5, 12.5], [9.5, 11], c= 'gold')
plt.plot([11.5, 12.5], [9.5, 9.5], c= 'gold')
plt.plot([11.5, 12.5], [11, 11], c= 'gold')


plt.xlim(-2, 24)
plt.ylim(2, 26)
# Out:
# (2.0, 26.0)
